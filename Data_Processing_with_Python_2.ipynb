#         9.74534084,  9.51680949,  9.97468744,  9.69694413, 10.32221548,
#        10.19401916,  9.6399592 , 10.41953335, 10.05678115,  9.8677999 ,
#        10.63823246, 10.54141664, 10.43533759, 10.05969632, 10.95517226])

# %%
plt.plot(np.sin(test_data), color='green')
plt.plot(np.cos(test_data), color='orange')
plt.savefig('noisysineandcosine.jpg')

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/thumb/b/b6/Queen_Elizabeth_II_in_March_2015.jpg/182px-Queen_Elizabeth_II_in_March_2015.jpg
# Out:
# --2022-09-10 16:00:17--  https://upload.wikimedia.org/wikipedia/commons/thumb/b/b6/Queen_Elizabeth_II_in_March_2015.jpg/182px-Queen_Elizabeth_II_in_March_2015.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 91.198.174.208, 2620:0:862:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|91.198.174.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13654 (13K) [image/jpeg]
# Saving to: ‘182px-Queen_Elizabeth_II_in_March_2015.jpg’
#
# 182px-Queen_Elizabe 100%[===================>]  13.33K  --.-KB/s    in 0s
#
# 2022-09-10 16:00:17 (126 MB/s) - ‘182px-Queen_Elizabeth_II_in_March_2015.jpg’ saved [13654/13654]

# %%
# !mv 182* queen.jpg

# %%
image_data = cv.imread('queen.jpg', 1)

# %%
rows, cols, channels = image_data.shape

# %%
print (rows, cols, channels)
# Out:
# 240 182 3

# %%
print(image_data)
# Out:
# [[[ 54  51  53]
#   [ 40  39  43]
#   [ 30  29  39]
#   ...
#   [130 158 192]
#   [141 165 193]
#   [145 168 194]]
#
#  [[ 36  34  40]
#   [ 28  25  34]
#   [ 19  19  33]
#   ...
#   [132 160 194]
#   [142 166 196]
#   [146 169 195]]
#
#  [[ 26  24  36]
#   [ 20  19  35]
#   [ 16  14  36]
#   ...
#   [130 160 195]
#   [140 165 197]
#   [144 168 196]]
#
#  ...
#
#  [[160  98 218]
#   [153  91 211]
#   [154  90 210]
#   ...
#   [181 132 246]
#   [181 132 246]
#   [180 131 245]]
#
#  [[152  91 213]
#   [154  93 215]
#   [155  93 213]
#   ...
#   [182 133 247]
#   [181 132 246]
#   [178 129 243]]
#
#  [[164 103 225]
#   [153  92 214]
#   [153  91 211]
#   ...
#   [181 132 246]
#   [178 129 243]
#   [173 124 238]]]

# %%
two_horizontal_queens = np.hstack((image_data, image_data))

# %%
cv2_imshow(two_horizontal_queens)
cv.imwrite('two-queens.jpg', two_horizontal_queens)
# Out:
# <PIL.Image.Image image mode=RGB size=364x240 at 0x7FB852CD6950>
# True

# %%
# slicing in Numerical Python
slice_portion = two_horizontal_queens[0:rows, cols:cols+cols, 0:channels]

# %%
slice_portion.shape
# Out:
# (240, 182, 3)

# %%
cv2_imshow(slice_portion)
# Out:
# <PIL.Image.Image image mode=RGB size=182x240 at 0x7FB8519C5990>

# %%
blurred_slice_portion = cv.blur(slice_portion, (5, 5))

# %%
cv2_imshow(blurred_slice_portion)
# Out:
# <PIL.Image.Image image mode=RGB size=182x240 at 0x7FB8519AA390>

# %%
cv2_imshow(two_horizontal_queens)
# Out:
# <PIL.Image.Image image mode=RGB size=364x240 at 0x7FB8519A5250>

# %%
two_horizontal_queens[0:rows, cols:cols+cols, 0:channels]  = blurred_slice_portion

# %%
cv2_imshow(two_horizontal_queens)
# Out:
# <PIL.Image.Image image mode=RGB size=364x240 at 0x7FB8519CEC50>
